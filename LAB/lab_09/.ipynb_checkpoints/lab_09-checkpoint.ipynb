# %%
import petModule as pm

# %%
pm.petStore()
# Out:
# Wellcome to Christ Pet Store
# Options
# ------------------
# 1.Store pet details
# 2.Search for a pet
# 3.Sell a pet
# 4.List all pets
# 5.Exit
# Enter Your Choice: 4
# dog []
# cat []
# rabbit []
# parrot []
# Wellcome to Christ Pet Store
# Options
# ------------------
# 1.Store pet details
# 2.Search for a pet
# 3.Sell a pet
# 4.List all pets
# 5.Exit
# Enter Your Choice: 1
# Enter pet type: dog
# Enter the Breed: bulldog
# Enter age of the pet(in months): 1
# Enter the Price: 300000
# Wellcome to Christ Pet Store
# Options
# ------------------
# 1.Store pet details
# 2.Search for a pet
# 3.Sell a pet
# 4.List all pets
# 5.Exit
# Enter Your Choice: 1
# Enter pet type: dog
# Enter the Breed: bulldog
# Enter age of the pet(in months): 3
# Enter the Price: 2000000
# Wellcome to Christ Pet Store
# Options
# ------------------
# 1.Store pet details
# 2.Search for a pet
# 3.Sell a pet
# 4.List all pets
# 5.Exit
# Enter Your Choice: 1
# Enter pet type: cat
# Enter the Breed: bombay cat
# ...
